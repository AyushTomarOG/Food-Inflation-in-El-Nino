# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from prophet import Prophet

# %%
CPI = pd.read_excel("cpi.xlsx")
ONI = pd.read_csv("oni.csv")

# %%
ONI.rename(columns={'  ONI from CPC  missing value -99.9 https://psl.noaa.gov/data/timeseries/month/': "ONI"}, inplace=True)

# %%
CPI.drop(["state", "sector", "group", "subgroup", "status"], axis=1, inplace=True)

# %%
ONI.tail(20)
# Out:
#            Date      ONI
# 904  01-05-2025    -0.02
# 905  01-06-2025    -0.04
# 906  01-07-2025    -0.14
# 907  01-08-2025    -0.28
# 908  01-09-2025    -0.40
# 909  01-10-2025    -0.51
# 910  01-11-2025    -0.55
# 911  01-12-2025    -0.54
# 912  01-01-2026    -0.37
# 913  01-02-2026    -0.14
# 914  01-03-2026     0.13
# 915  01-04-2026     0.51
# 916  01-05-2026     0.98
# 917  01-06-2026 -9999.00
# 918  01-07-2026 -9999.00
# 919  01-08-2026 -9999.00
# 920  01-09-2026 -9999.00
# 921  01-10-2026 -9999.00
# 922  01-11-2026 -9999.00
# 923  01-12-2026 -9999.00
